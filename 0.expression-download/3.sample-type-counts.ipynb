# %% [markdown]
# # Describe tissue types of input data
#
# **Gregory Way, 2019**
#
# Load in previously identified tissue type counts and output a supplementary table.

# %%
import os
import pandas as pd

# %%
# Load TCGA data
file = os.path.join('data', 'tcga_sample_counts.tsv')
tcga_count_df = pd.read_table(file, sep='\t').rename({'cancertype': 'tissue'}, axis='columns')
tcga_count_df = tcga_count_df.assign(dataset="TCGA")
tcga_count_df.head()
# Out:
#   tissue   n = dataset
# 0   BRCA  1218    TCGA
# 1   KIRC   606    TCGA
# 2   LUAD   576    TCGA
# 3   THCA   572    TCGA
# 4   UCEC   567    TCGA

# %%
# Load GTEX data
file = os.path.join('data', 'gtex_sample_counts.tsv')
gtex_count_df = pd.read_table(file, sep='\t').rename({'tissuetype': 'tissue'}, axis='columns')
gtex_count_df = gtex_count_df.assign(dataset="GTEX")
gtex_count_df.head()
# Out:
#                            tissue  n = dataset
# 0               Muscle - Skeletal  564    GTEX
# 1  Skin - Sun Exposed (Lower leg)  473    GTEX
# 2                         Thyroid  446    GTEX
# 3          Adipose - Subcutaneous  442    GTEX
# 4                 Artery - Tibial  441    GTEX

# %%
# Load TARGET data
file = os.path.join('data', 'target_sample_counts.tsv')
target_count_df = pd.read_table(file, sep='\t').rename({'cancertype': 'tissue'}, axis='columns')
target_count_df = target_count_df.assign(dataset="TARGET")
target_count_df.head()
# Out:
#    tissue  n = dataset
# 0     AML  196  TARGET
# 1     ALL  194  TARGET
# 2     NBL  162  TARGET
# 3      WT  132  TARGET
# 4  AML-IF   32  TARGET

# %%
# Combine all data to generate supplementary table
full_count_df = (
    pd.concat([tcga_count_df, gtex_count_df, target_count_df], axis='rows')
    .sort_values(by='tissue', ascending=True)
    .reset_index(drop=True)
)


file = os.path.join('results', 'full_sample_counts.tsv')
full_count_df.to_csv(file, sep='\t', index=False)

full_count_df
# Out:
#                                        tissue   n = dataset
# 0                                         ACC    79    TCGA
# 1                                         ALL   194  TARGET
# 2                                         AML   196  TARGET
# 3                                      AML-IF    32  TARGET
# 4                      Adipose - Subcutaneous   442    GTEX
# 5                Adipose - Visceral (Omentum)   355    GTEX
# 6                               Adrenal Gland   190    GTEX
# 7                              Artery - Aorta   299    GTEX
# 8                           Artery - Coronary   173    GTEX
# 9                             Artery - Tibial   441    GTEX
# 10                                       BLCA   427    TCGA
# 11                                       BRCA  1218    TCGA
# 12                                    Bladder    11    GTEX
# 13                           Brain - Amygdala   100    GTEX
# 14   Brain - Anterior cingulate cortex (BA24)   121    GTEX
# 15            Brain - Caudate (basal ganglia)   160    GTEX
# 16              Brain - Cerebellar Hemisphere   136    GTEX
# 17                         Brain - Cerebellum   173    GTEX
# 18                             Brain - Cortex   158    GTEX
# 19               Brain - Frontal Cortex (BA9)   129    GTEX
# 20                        Brain - Hippocampus   123    GTEX
# 21                       Brain - Hypothalamus   121    GTEX
# 22  Brain - Nucleus accumbens (basal ganglia)   147    GTEX
# 23            Brain - Putamen (basal ganglia)   124    GTEX
# 24         Brain - Spinal cord (cervical c-1)    91    GTEX
# 25                   Brain - Substantia nigra    88    GTEX
# 26                    Breast - Mammary Tissue   290    GTEX
# 27                                       CCSK    13  TARGET
# 28                                       CESC   310    TCGA
# 29                                       CHOL    45    TCGA
# ..                                        ...   ...     ...
# 63                                         OV   308    TCGA
# 64                                      Ovary   133    GTEX
# 65                                       PAAD   183    TCGA
# 66                                       PCPG   187    TCGA
# 67                                       PRAD   550    TCGA
# 68                                   Pancreas   248    GTEX
# 69                                  Pituitary   183    GTEX
# 70                                   Prostate   152    GTEX
# 71                                       READ   171    TCGA
# 72                                         RT     5  TARGET
# 73                                       SARC   265    TCGA
# 74                                       SKCM   474    TCGA
# 75                                       STAD   450    TCGA
# 76        Skin - Not Sun Exposed (Suprapubic)   387    GTEX
# 77             Skin - Sun Exposed (Lower leg)   473    GTEX
# 78           Small Intestine - Terminal Ileum   137    GTEX
# 79                                     Spleen   162    GTEX
# 80                                    Stomach   262    GTEX
# 81                                       TGCT   156    TCGA
# 82                                       THCA   572    TCGA
# 83                                       THYM   122    TCGA
# 84                                     Testis   259    GTEX
# 85                                    Thyroid   446    GTEX
# 86                                       UCEC   567    TCGA
# 87                                        UCS    57    TCGA
# 88                                        UVM    80    TCGA
# 89                                     Uterus   111    GTEX
# 90                                     Vagina   115    GTEX
# 91                                         WT   132  TARGET
# 92                                Whole Blood   407    GTEX
#
# [93 rows x 3 columns]
