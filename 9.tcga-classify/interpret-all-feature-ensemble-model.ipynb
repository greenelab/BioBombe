# %% [markdown]
# ## Generating a Table of the BioBombe Interpreted Features in the All Feature Ensemble model of TP53 inactivation
#
# **Gregory Way, 2019**
#
# I use the model previously identified that was used to predict TP53 inactivation.
# I observe the BioBombe gene set enrichment scores for the features with high coefficients in this model.

# %%
import os
import sys
import pandas as pd

# %% [markdown]
# ## Load the `All Feature` Ensemble Model

# %%
model_file = os.path.join("results", "top_model_ensemble_all_features_tp53_feature_for_followup.tsv")
top_model_df = pd.read_table(model_file)
top_model_df
# Out:
#    gene  signal z_dim                   seed             algorithm  weight  \
# 0  TP53  signal   all  ensemble_all_features  all_feature_ensemble   30555
#
#    num_features  percent_zero    auroc     aupr data_type
# 0         30872      0.989732  0.91202  0.88231        cv

# %%
coef_file = os.path.join("results",
                         "mutation_ensemble_all",
                         "TP53",
                         "TP53_ensemble_all_features_coefficients.tsv.gz")
coef_df = pd.read_table(coef_file).drop(['signal', 'z_dim', 'seed', 'algorithm'], axis='columns')
coef_df.head()
# Out:
#                      feature    weight       abs  gene
# 0  vae_133_978124_200_signal  0.082262  0.082262  TP53
# 1     vae_6_908341_50_signal  0.075826  0.075826  TP53
# 2    vae_4_908341_150_signal -0.065103  0.065103  TP53
# 3  dae_140_451283_150_signal -0.062348  0.062348  TP53
# 4   nmf_97_486191_200_signal -0.061847  0.061847  TP53

# %%
full_coef_id_df = (
    pd.DataFrame(coef_df.feature.str.split("_").values.tolist(),
                 columns=['algorithm', 'individual_feature', 'seed', 'k', 'signal'])
)

full_coef_id_df = pd.concat([full_coef_id_df, coef_df], axis='columns')
full_coef_id_df = full_coef_id_df.query("abs > 0").query("signal == 'signal'")

print(full_coef_id_df.shape)
full_coef_id_df.head()
# Out:
# (317, 9)
#   algorithm individual_feature    seed    k  signal  \
# 0       vae                133  978124  200  signal
# 1       vae                  6  908341   50  signal
# 2       vae                  4  908341  150  signal
# 3       dae                140  451283  150  signal
# 4       nmf                 97  486191  200  signal
#
#                      feature    weight       abs  gene
# 0  vae_133_978124_200_signal  0.082262  0.082262  TP53
# 1     vae_6_908341_50_signal  0.075826  0.075826  TP53
# 2    vae_4_908341_150_signal -0.065103  0.065103  TP53
# 3  dae_140_451283_150_signal -0.062348  0.062348  TP53
# 4   nmf_97_486191_200_signal -0.061847  0.061847  TP53

# %% [markdown]
# ## Load Network Projection Results

# %%
gph_dir = os.path.join("..",
                       "6.biobombe-projection",
                       "results",
                       "tcga",
                       "gph",
                       "signal")
gph_files = os.listdir(gph_dir)

# %%
all_scores_list = []
for file in gph_files:
    file = os.path.join(gph_dir, file)
    scores_df = pd.read_table(file)
    all_scores_list.append(scores_df)

# %%
all_scores_df = pd.concat(all_scores_list, axis='rows')

print(all_scores_df.shape)
all_scores_df.head()
# Out:
# (1542500, 8)
#   model_type                          variable     value  z_score algorithm  \
# 0       real  HALLMARK_TNFA_SIGNALING_VIA_NFKB -0.011890 -34.8593       ica
# 1       real  HALLMARK_TNFA_SIGNALING_VIA_NFKB -0.010828 -25.8855       ica
# 2       real    HALLMARK_XENOBIOTIC_METABOLISM -0.019012 -25.6744       ica
# 3       real    HALLMARK_XENOBIOTIC_METABOLISM -0.018991 -25.2048       ica
# 4       real           HALLMARK_G2M_CHECKPOINT -0.021909 -23.2724       ica
#
#    feature  z    seed
# 0        5  8  165158
# 1        4  8  978124
# 2        3  8  451283
# 3        6  8  486191
# 4        5  8  908341

# %%
all_scores_df = all_scores_df.assign(big_feature_id=all_scores_df.algorithm + "_" +
                                     all_scores_df.feature.astype(str) + "_" +
                                     all_scores_df.seed.astype(str) + "_" +
                                     all_scores_df.z.astype(str) + "_signal")
all_scores_df = all_scores_df.assign(abs_z_score=all_scores_df.z_score.abs())

# %%
all_coef_scores_df = (
    full_coef_id_df
    .merge(all_scores_df,
           how='left',
           left_on="feature",
           right_on="big_feature_id")
    .sort_values(by=['abs', 'abs_z_score'], ascending=False)
    .reset_index(drop=True)
)

all_coef_scores_df.head()
# Out:
#   algorithm_x individual_feature  seed_x    k  signal  \
# 0         vae                133  978124  200  signal
# 1         vae                133  978124  200  signal
# 2         vae                133  978124  200  signal
# 3         vae                133  978124  200  signal
# 4         vae                133  978124  200  signal
#
#                    feature_x    weight       abs  gene model_type  \
# 0  vae_133_978124_200_signal  0.082262  0.082262  TP53       real
# 1  vae_133_978124_200_signal  0.082262  0.082262  TP53       real
# 2  vae_133_978124_200_signal  0.082262  0.082262  TP53       real
# 3  vae_133_978124_200_signal  0.082262  0.082262  TP53       real
# 4  vae_133_978124_200_signal  0.082262  0.082262  TP53       real
#
#                            variable    value   z_score algorithm_y  feature_y  \
# 0  HALLMARK_ESTROGEN_RESPONSE_EARLY -3.89942 -10.50850         vae        133
# 1   HALLMARK_ESTROGEN_RESPONSE_LATE -4.34600  -6.83035         vae        133
# 2              HALLMARK_P53_PATHWAY -3.46517  -6.42001         vae        133
# 3              HALLMARK_COAGULATION -2.60747  -6.38283         vae        133
# 4    HALLMARK_XENOBIOTIC_METABOLISM -3.64404  -6.15825         vae        133
#
#      z  seed_y             big_feature_id  abs_z_score
# 0  200  978124  vae_133_978124_200_signal     10.50850
# 1  200  978124  vae_133_978124_200_signal      6.83035
# 2  200  978124  vae_133_978124_200_signal      6.42001
# 3  200  978124  vae_133_978124_200_signal      6.38283
# 4  200  978124  vae_133_978124_200_signal      6.15825

# %%
# Explore the biobombe scores for specific DAE features
top_n_features = 5

biobombe_df = (
    all_coef_scores_df
    .groupby('big_feature_id')
    .apply(func=lambda x: x.abs_z_score.nlargest(top_n_features))
    .reset_index()
    .merge(all_coef_scores_df
           .reset_index(),
           right_on=['index', 'abs_z_score', 'big_feature_id'],
           left_on=['level_1', 'abs_z_score', 'big_feature_id'])
    .drop(['level_1', 'index', 'feature_x',
           'algorithm_x', 'seed_x',
           'model_type', 'algorithm_y',
           'feature_y', 'seed_y', 'z'], axis='columns')
    .sort_values(by=['abs', 'abs_z_score'], ascending=False)
    .reset_index(drop=True)
)

print(biobombe_df.shape)
biobombe_df.head(20)
# Out:
# (1585, 11)
#                big_feature_id  abs_z_score individual_feature    k  signal  \
# 0   vae_133_978124_200_signal     10.50850                133  200  signal
# 1   vae_133_978124_200_signal      6.83035                133  200  signal
# 2   vae_133_978124_200_signal      6.42001                133  200  signal
# 3   vae_133_978124_200_signal      6.38283                133  200  signal
# 4   vae_133_978124_200_signal      6.15825                133  200  signal
# 5      vae_6_908341_50_signal     13.41920                  6   50  signal
# 6      vae_6_908341_50_signal     10.68800                  6   50  signal
# 7      vae_6_908341_50_signal      7.52623                  6   50  signal
# 8      vae_6_908341_50_signal      7.41978                  6   50  signal
# 9      vae_6_908341_50_signal      6.68337                  6   50  signal
# 10    vae_4_908341_150_signal      8.68153                  4  150  signal
# 11    vae_4_908341_150_signal      7.60301                  4  150  signal
# 12    vae_4_908341_150_signal      6.80611                  4  150  signal
# 13    vae_4_908341_150_signal      5.90416                  4  150  signal
# 14    vae_4_908341_150_signal      5.87387                  4  150  signal
# 15  dae_140_451283_150_signal      8.40018                140  150  signal
# 16  dae_140_451283_150_signal      3.81763                140  150  signal
# 17  dae_140_451283_150_signal      3.61020                140  150  signal
# 18  dae_140_451283_150_signal      3.43927                140  150  signal
# 19  dae_140_451283_150_signal      3.09878                140  150  signal
#
#       weight       abs  gene                                    variable  \
# 0   0.082262  0.082262  TP53            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 1   0.082262  0.082262  TP53             HALLMARK_ESTROGEN_RESPONSE_LATE
# 2   0.082262  0.082262  TP53                        HALLMARK_P53_PATHWAY
# 3   0.082262  0.082262  TP53                        HALLMARK_COAGULATION
# 4   0.082262  0.082262  TP53              HALLMARK_XENOBIOTIC_METABOLISM
# 5   0.075826  0.075826  TP53            HALLMARK_TNFA_SIGNALING_VIA_NFKB
# 6   0.075826  0.075826  TP53              HALLMARK_XENOBIOTIC_METABOLISM
# 7   0.075826  0.075826  TP53                        HALLMARK_COAGULATION
# 8   0.075826  0.075826  TP53                     HALLMARK_MYC_TARGETS_V1
# 9   0.075826  0.075826  TP53                  HALLMARK_KRAS_SIGNALING_UP
# 10 -0.065103  0.065103  TP53               HALLMARK_BILE_ACID_METABOLISM
# 11 -0.065103  0.065103  TP53  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 12 -0.065103  0.065103  TP53              HALLMARK_FATTY_ACID_METABOLISM
# 13 -0.065103  0.065103  TP53          HALLMARK_OXIDATIVE_PHOSPHORYLATION
# 14 -0.065103  0.065103  TP53            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 15 -0.062348  0.062348  TP53          HALLMARK_INTERFERON_ALPHA_RESPONSE
# 16 -0.062348  0.062348  TP53          HALLMARK_INTERFERON_GAMMA_RESPONSE
# 17 -0.062348  0.062348  TP53            HALLMARK_CHOLESTEROL_HOMEOSTASIS
# 18 -0.062348  0.062348  TP53    HALLMARK_REACTIVE_OXIGEN_SPECIES_PATHWAY
# 19 -0.062348  0.062348  TP53             HALLMARK_ESTROGEN_RESPONSE_LATE
#
#        value   z_score
# 0  -3.899420 -10.50850
# 1  -4.346000  -6.83035
# 2  -3.465170  -6.42001
# 3  -2.607470  -6.38283
# 4  -3.644040  -6.15825
# 5  -4.420490 -13.41920
# 6  -5.684370 -10.68800
# 7  -4.084820  -7.52623
# 8   0.408717   7.41978
# 9  -4.511470  -6.68337
# 10  0.070708   8.68153
# 11 -4.435280  -7.60301
# 12 -0.831578   6.80611
# 13 -0.547640   5.90416
# 14 -0.789038   5.87387
# 15 -3.109890  -8.40018
# 16 -2.360520  -3.81763
# 17  1.303720   3.61020
# 18 -0.811733  -3.43927
# 19  1.683600   3.09878

# %%
# Output biobombe scores applied to the all feature ensemble model
file = os.path.join('results', 'tcga_tp53_classify_top_biobombe_scores_all_feature_ensemble_model_table.tsv')
biobombe_df.to_csv(file, sep='\t', index=False)

# %% [markdown]
# ## Detect the highest contributing variables

# %%
neg_biobombe_df = biobombe_df.query("weight < 0")
pos_biobombe_df = biobombe_df.query("weight > 0")

top_neg_variables_df = neg_biobombe_df.groupby("variable")['weight'].sum().sort_values(ascending=True)
top_pos_variables_df = pos_biobombe_df.groupby("variable")['weight'].sum().sort_values(ascending=False)

# %%
full_result_df = pd.DataFrame(pd.concat([top_pos_variables_df, top_neg_variables_df]))
full_result_df = (
    full_result_df
    .assign(abs_weight=full_result_df.weight.abs())
    .sort_values(by='abs_weight', ascending=False)
)

full_result_df.head()
# Out:
#                                               weight  abs_weight
# variable
# HALLMARK_MYC_TARGETS_V1                     1.159295    1.159295
# HALLMARK_G2M_CHECKPOINT                     1.029499    1.029499
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -1.028895    1.028895
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  0.977735    0.977735
# HALLMARK_E2F_TARGETS                        0.946652    0.946652

# %%
# Output biobombe scores applied to the all feature ensemble model
file = os.path.join('results', 'tcga_tp53_classify_aggregate_biobombe_scores_all_feature_ensemble.tsv')
full_result_df.to_csv(file, sep='\t', index=False)
