# %% [markdown]
# # Process GTEx Gene Expression Data
#
# Retrieve the downloaded expression data, update gene identifiers to entrez, and curate sample IDs. The script will also identify a balanced hold-out test set to compare projection performance into learned latent spaces across algorithms.
#
# **Note:** GTEx version 7 was downloaded from https://www.gtexportal.org/home/datasets

# %%
import os
import random
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
random.seed(1234)

# %% [markdown]
# ## Read Phenotype Information

# %%
path = os.path.join('download', 'GTEx_v7_Annotations_SampleAttributesDS.txt')
pheno_df = pd.read_table(path)

print(pheno_df.shape)
pheno_df.head(3)
# Out:
# (15598, 63)
#                      SAMPID  SMATSSCR SMCENTER SMPTHNTS  SMRIN   SMTS  \
# 0  GTEX-1117F-0003-SM-58Q7G       NaN       B1      NaN    NaN  Blood
# 1  GTEX-1117F-0003-SM-5DWSB       NaN       B1      NaN    NaN  Blood
# 2  GTEX-1117F-0003-SM-6WBT7       NaN       B1      NaN    NaN  Blood
#
#          SMTSD  SMUBRID  SMTSISCH  SMTSPAX    ...    SME1ANTI SMSPLTRD  \
# 0  Whole Blood  0013756    1188.0      NaN    ...         NaN      NaN
# 1  Whole Blood  0013756    1188.0      NaN    ...         NaN      NaN
# 2  Whole Blood  0013756    1188.0      NaN    ...         NaN      NaN
#
#   SMBSMMRT SME1SNSE SME1PCTS SMRRNART SME1MPRT SMNUM5CD  SMDPMPRT  SME2PCTS
# 0      NaN      NaN      NaN      NaN      NaN      NaN       NaN       NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN       NaN       NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN       NaN       NaN
#
# [3 rows x 63 columns]

# %% [markdown]
# ## Read Entrez ID Curation Information
#
# Load curated gene names from versioned resource. See https://github.com/cognoma/genes for more details

# %%
# Commit from https://github.com/cognoma/genes
genes_commit = 'ad9631bb4e77e2cdc5413b0d77cb8f7e93fc5bee'

# %%
url = 'https://raw.githubusercontent.com/cognoma/genes/{}/data/genes.tsv'.format(genes_commit)
gene_df = pd.read_table(url)

# Only consider protein-coding genes
gene_df = (
    gene_df.query("gene_type == 'protein-coding'")
)

print(gene_df.shape)
gene_df.head(2)
# Out:
# (20395, 7)
#    entrez_gene_id symbol             description chromosome       gene_type  \
# 0               1   A1BG  alpha-1-B glycoprotein         19  protein-coding
# 1               2    A2M   alpha-2-macroglobulin         12  protein-coding
#
#                     synonyms  \
# 0       A1B|ABG|GAB|HYST2477
# 1  A2MD|CPAMD5|FWP007|S863-7
#
#                                              aliases
# 0  alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...
# 1  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...

# %%
# Load gene updater - old to new Entrez gene identifiers
url = 'https://raw.githubusercontent.com/cognoma/genes/{}/data/updater.tsv'.format(genes_commit)
updater_df = pd.read_table(url)
old_to_new_entrez = dict(zip(updater_df.old_entrez_gene_id,
                             updater_df.new_entrez_gene_id))

# %% [markdown]
# ## Read Gene Expression Data

# %%
file = os.path.join('download', 'GTEx_Analysis_2016-01-15_v7_RNASeQCv1.1.8_gene_tpm.gct.gz')
expr_df = pd.read_table(file, sep='\t', skiprows=2, index_col=1)

print(expr_df.shape)

expr_df.head(2)
# Out:
# (56202, 11689)
#                           Name  GTEX-1117F-0226-SM-5GZZ7  \
# Description
# DDX11L1      ENSG00000223972.4                    0.1082
# WASH7P       ENSG00000227232.4                   21.4000
#
#              GTEX-111CU-1826-SM-5GZYN  GTEX-111FC-0226-SM-5N9B8  \
# Description
# DDX11L1                        0.1158                   0.02104
# WASH7P                        11.0300                  16.75000
#
#              GTEX-111VG-2326-SM-5N9BK  GTEX-111YS-2426-SM-5GZZQ  \
# Description
# DDX11L1                       0.02329                     0.000
# WASH7P                        8.17200                     7.658
#
#              GTEX-1122O-2026-SM-5NQ91  GTEX-1128S-2126-SM-5H12U  \
# Description
# DDX11L1                       0.04641                   0.03076
# WASH7P                        9.37200                  10.08000
#
#              GTEX-113IC-0226-SM-5HL5C  GTEX-117YX-2226-SM-5EGJJ  \
# Description
# DDX11L1                       0.09358                     0.121
# WASH7P                       13.56000                     9.889
#
#                       ...             GTEX-ZVE2-0006-SM-51MRW  \
# Description           ...
# DDX11L1               ...                             0.09012
# WASH7P                ...                             3.92600
#
#              GTEX-ZVP2-0005-SM-51MRK  GTEX-ZVT2-0005-SM-57WBW  \
# Description
# DDX11L1                       0.1462                   0.1045
# WASH7P                       13.1300                   5.5370
#
#              GTEX-ZVT3-0006-SM-51MT9  GTEX-ZVT4-0006-SM-57WB8  \
# Description
# DDX11L1                        0.000                   0.6603
# WASH7P                         5.789                   8.4390
#
#              GTEX-ZVTK-0006-SM-57WBK  GTEX-ZVZP-0006-SM-51MSW  \
# Description
# DDX11L1                        0.695                   0.1213
# WASH7P                         7.843                  12.3900
#
#              GTEX-ZVZQ-0006-SM-51MR8  GTEX-ZXES-0005-SM-57WCB  \
# Description
# DDX11L1                       0.4169                   0.2355
# WASH7P                       12.5300                   8.0270
#
#              GTEX-ZXG5-0005-SM-57WCN
# Description
# DDX11L1                        0.145
# WASH7P                        12.760
#
# [2 rows x 11689 columns]

# %%
# Get GTEx gene mapping
expr_gene_ids = (
    expr_df
    .loc[:, ['Name']]
    .reset_index()
    .drop_duplicates(subset='Description')
)

# Inner merge gene df to get ensembl to entrez mapping
map_df = expr_gene_ids.merge(gene_df, how='inner', left_on='Description', right_on='symbol')

symbol_to_entrez = dict(zip(map_df.symbol, map_df.entrez_gene_id))

# %% [markdown]
# ## Process gene expression matrix
#
# This involves updating Entrez gene ids, sorting and subsetting

# %%
expr_df = (expr_df
 .drop(['Name'], axis='columns')
 .dropna(axis='rows')
 .groupby(level=0).mean()
 .reindex(map_df.symbol)
 .rename(index=symbol_to_entrez)
 .rename(index=old_to_new_entrez)
 .transpose()
 .sort_index(axis='rows')
 .sort_index(axis='columns')
)

expr_df.index.rename('sample_id', inplace=True)

print(expr_df.shape)
expr_df.head(2)
# Out:
# (11688, 18356)
# symbol                    1          2          9          10         \
# sample_id
# GTEX-1117F-0226-SM-5GZZ7     4.9610      356.1     2.0350     0.2791
# GTEX-1117F-0426-SM-5EGHI     0.6198      110.0     0.2491     0.0000
#
# symbol                    12         13         14         15         \
# sample_id
# GTEX-1117F-0226-SM-5GZZ7      48.12     1.4010     174.40     0.4212
# GTEX-1117F-0426-SM-5EGHI       5.08     0.1115      78.17     0.1274
#
# symbol                    16         18           ...      101180976  \
# sample_id                                         ...
# GTEX-1117F-0226-SM-5GZZ7      71.11      7.744    ...            0.0
# GTEX-1117F-0426-SM-5EGHI      53.43      6.029    ...            0.0
#
# symbol                    101241878  101362076  101928601  102723547  \
# sample_id
# GTEX-1117F-0226-SM-5GZZ7        0.0     1.6460     0.1025        0.0
# GTEX-1117F-0426-SM-5EGHI        0.0     0.4977     0.0000        0.0
#
# symbol                    102724231  102724473  102724928  105375355  \
# sample_id
# GTEX-1117F-0226-SM-5GZZ7      2.521        0.0        0.0    10.5300
# GTEX-1117F-0426-SM-5EGHI      1.525        0.0        0.0     0.8182
#
# symbol                    105378803
# sample_id
# GTEX-1117F-0226-SM-5GZZ7    0.03187
# GTEX-1117F-0426-SM-5EGHI    0.00000
#
# [2 rows x 18356 columns]

# %% [markdown]
# ## Stratify Balanced Training and Testing Sets in GTEx Gene Expression
#
# Output training and testing gene expression datasets.

# %%
strat = pheno_df.set_index('SAMPID').reindex(expr_df.index).SMTSD

# %%
tissuetype_count_df = (
    pd.DataFrame(strat.value_counts())
    .reset_index()
    .rename({'index': 'tissuetype', 'SMTSD': 'n ='}, axis='columns')
)

file = os.path.join('data', 'gtex_sample_counts.tsv')
tissuetype_count_df.to_csv(file, sep='\t', index=False)

tissuetype_count_df
# Out:
#                                    tissuetype  n =
# 0                           Muscle - Skeletal  564
# 1              Skin - Sun Exposed (Lower leg)  473
# 2                                     Thyroid  446
# 3                      Adipose - Subcutaneous  442
# 4                             Artery - Tibial  441
# 5                                        Lung  427
# 6                              Nerve - Tibial  414
# 7                                 Whole Blood  407
# 8                          Esophagus - Mucosa  407
# 9         Skin - Not Sun Exposed (Suprapubic)  387
# 10                     Esophagus - Muscularis  370
# 11               Adipose - Visceral (Omentum)  355
# 12            Cells - Transformed fibroblasts  343
# 13                     Heart - Left Ventricle  303
# 14                             Artery - Aorta  299
# 15                   Heart - Atrial Appendage  297
# 16                    Breast - Mammary Tissue  290
# 17                         Colon - Transverse  274
# 18                                    Stomach  262
# 19                                     Testis  259
# 20                                   Pancreas  248
# 21      Esophagus - Gastroesophageal Junction  244
# 22                            Colon - Sigmoid  233
# 23                              Adrenal Gland  190
# 24                                  Pituitary  183
# 25                                      Liver  175
# 26                         Brain - Cerebellum  173
# 27                          Artery - Coronary  173
# 28                                     Spleen  162
# 29            Brain - Caudate (basal ganglia)  160
# 30                             Brain - Cortex  158
# 31                                   Prostate  152
# 32  Brain - Nucleus accumbens (basal ganglia)  147
# 33           Small Intestine - Terminal Ileum  137
# 34              Brain - Cerebellar Hemisphere  136
# 35                                      Ovary  133
# 36        Cells - EBV-transformed lymphocytes  130
# 37               Brain - Frontal Cortex (BA9)  129
# 38            Brain - Putamen (basal ganglia)  124
# 39                        Brain - Hippocampus  123
# 40                       Brain - Hypothalamus  121
# 41   Brain - Anterior cingulate cortex (BA24)  121
# 42                                     Vagina  115
# 43                                     Uterus  111
# 44                           Brain - Amygdala  100
# 45                       Minor Salivary Gland   97
# 46         Brain - Spinal cord (cervical c-1)   91
# 47                   Brain - Substantia nigra   88
# 48                            Kidney - Cortex   45
# 49                                    Bladder   11
# 50                             Fallopian Tube    7
# 51                        Cervix - Ectocervix    6
# 52                        Cervix - Endocervix    5

# %%
train_df, test_df = train_test_split(expr_df,
                                     test_size=0.1,
                                     random_state=123,
                                     stratify=strat)

# %%
print(train_df.shape)
test_df.shape
# Out:
# (10519, 18356)
# (1169, 18356)

# %%
train_file = os.path.join('data', 'train_gtex_expression_matrix_processed.tsv.gz')
train_df.to_csv(train_file, sep='\t', compression='gzip', float_format='%.3g')

# %%
test_file = os.path.join('data', 'test_gtex_expression_matrix_processed.tsv.gz')
test_df.to_csv(test_file, sep='\t', compression='gzip', float_format='%.3g')

# %% [markdown]
# ## Sort genes based on median absolute deviation and output to file

# %%
# Determine most variably expressed genes and subset
mad_genes_df = pd.DataFrame(train_df.mad(axis=0).sort_values(ascending=False)).reset_index()
mad_genes_df.columns = ['gene_id', 'median_absolute_deviation']

file = os.path.join('data', 'gtex_mad_genes.tsv')
mad_genes_df.to_csv(file, sep='\t', index=False)
