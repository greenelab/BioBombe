# %% [markdown]
# ## Generating a Table of the BioBombe Interpreted Features in a High Scoring DAE model of TP53 inactivation
#
# **Gregory Way, 2019**
#
# I use the model previously identified that was used to predict TP53 inactivation.
# I observe the BioBombe gene set enrichment scores for the features with high coefficients in this model.

# %%
import os
import sys
import pandas as pd

# %% [markdown]
# ## Load the Top Model Identified Previously

# %%
model_file = os.path.join("results", "top_dae_tp53_feature_for_followup.tsv")
top_model_df = pd.read_table(model_file)
top_model_df
# Out:
#    gene  signal  z_dim    seed algorithm  weight  num_features  percent_zero  \
# 0  TP53  signal    200  908341       DAE     179           222      0.806306
#
#      auroc     aupr data_type   grouping_  auroc_raw  aupr_raw z_dim_shape
# 0  0.86364  0.82745        cv  TP53signal    0.91836   0.88467     z >= 20

# %%
seed = top_model_df.seed.values[0]
z_dim = top_model_df.z_dim.values[0]
algorithm = top_model_df.algorithm.values[0].lower()

# %% [markdown]
# ## Load the BioBombe network projection results for Cancer Hallmarks

# %%
file = os.path.join("..", "6.analyze-weights", "results", "tcga",
                    "gph", "signal", "tcga_z_200_GpH__geneset_scores.tsv.gz")

scores_df = (
    pd
    .read_table(file)
    .query("seed == @seed")
    .query("z == @z_dim")
    .query("algorithm == @algorithm")
)

scores_df = (
    scores_df
    .assign(full_feature=scores_df.algorithm.astype(str) + "_" + scores_df.feature.astype(str),
            abs_z_score=scores_df.z_score.abs())
)
scores_df.head()
# Out:
#    model_type                                    variable    value  z_score  \
# 17       real            HALLMARK_TNFA_SIGNALING_VIA_NFKB -10.7069 -19.8077
# 27       real                     HALLMARK_G2M_CHECKPOINT -15.2559 -19.1039
# 32       real  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -12.6927 -17.7711
# 62       real  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -13.4749 -15.7488
# 88       real  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -11.1642 -14.7547
#
#    algorithm  feature    z    seed full_feature  abs_z_score
# 17       dae      170  200  908341      dae_170      19.8077
# 27       dae      110  200  908341      dae_110      19.1039
# 32       dae       99  200  908341       dae_99      17.7711
# 62       dae      192  200  908341      dae_192      15.7488
# 88       dae       73  200  908341       dae_73      14.7547

# %% [markdown]
# ## Load Model Coefficients

# %%
file = os.path.join("results", "mutation", "TP53", "TP53_coefficients.tsv.gz")

top_n_features = 8

coef_df = (
    pd.read_table(file)
    .query("seed == @seed")
    .query("z_dim == @z_dim")
    .query("algorithm == @algorithm")
    .query("signal == 'signal'")
    .sort_values(by='abs', ascending=False)
    .head(top_n_features)
)

use_features = coef_df.feature.tolist()
coef_df
# Out:
#         feature   weight      abs  signal  z_dim    seed algorithm  gene
# 6201    dae_156  0.23558  0.23558  signal    200  908341       dae  TP53
# 6202     dae_46 -0.22864  0.22864  signal    200  908341       dae  TP53
# 6203    dae_122  0.19832  0.19832  signal    200  908341       dae  TP53
# 6204     dae_24 -0.18192  0.18192  signal    200  908341       dae  TP53
# 6205  log10_mut  0.17411  0.17411  signal    200  908341       dae  TP53
# 6206      dae_7  0.16581  0.16581  signal    200  908341       dae  TP53
# 6207    dae_130 -0.16391  0.16391  signal    200  908341       dae  TP53
# 6208     dae_88 -0.15494  0.15494  signal    200  908341       dae  TP53

# %%
# Explore the biobombe scores for specific DAE features
top_n_features = 10

biobombe_df = (
    scores_df
    .query("full_feature in @use_features")
    .merge(coef_df,
           how='left',
           left_on=['full_feature', 'algorithm', 'seed'],
           right_on=['feature', 'algorithm', 'seed'])
    .drop(['model_type', 'feature_x', 'feature_y', 'signal'], axis='columns')
    .sort_values(by=['abs', 'abs_z_score'], ascending=False)
    .reset_index(drop=True)
)

top_biobombe_df = (
    biobombe_df
    .groupby('full_feature')
    .apply(func=lambda x: x.abs_z_score.nlargest(top_n_features))
    .reset_index()
    .merge(biobombe_df
           .reset_index(),
           right_on=['index', 'abs_z_score', 'full_feature'],
           left_on=['level_1', 'abs_z_score', 'full_feature'])
    .drop(['level_1', 'index'], axis='columns')
    .sort_values(by=['weight', 'z_score'], ascending=False)
)
    
    
print(top_biobombe_df.shape)
top_biobombe_df
# Out:
# (70, 12)
#    full_feature  abs_z_score                                    variable  \
# 21      dae_156      4.48129          HALLMARK_INTERFERON_GAMMA_RESPONSE
# 24      dae_156      3.16951                    HALLMARK_HEME_METABOLISM
# 25      dae_156      3.08817          HALLMARK_INTERFERON_ALPHA_RESPONSE
# 27      dae_156      2.90375                     HALLMARK_UV_RESPONSE_UP
# 28      dae_156      2.77715             HALLMARK_ESTROGEN_RESPONSE_LATE
# 29      dae_156      2.76895                            HALLMARK_HYPOXIA
# 26      dae_156      3.04312          HALLMARK_OXIDATIVE_PHOSPHORYLATION
# 23      dae_156      3.64827                         HALLMARK_COMPLEMENT
# 22      dae_156      4.11478                  HALLMARK_KRAS_SIGNALING_UP
# 20      dae_156      4.92812                        HALLMARK_COAGULATION
# 0       dae_122      7.87064  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 1       dae_122      4.96567            HALLMARK_TNFA_SIGNALING_VIA_NFKB
# 4       dae_122      4.46584                   HALLMARK_MTORC1_SIGNALING
# 5       dae_122      4.22858                            HALLMARK_HYPOXIA
# 9       dae_122      3.15448                         HALLMARK_GLYCOLYSIS
# 8       dae_122      3.29913                     HALLMARK_APICAL_SURFACE
# 7       dae_122      3.38226              HALLMARK_XENOBIOTIC_METABOLISM
# 6       dae_122      3.42185                    HALLMARK_SPERMATOGENESIS
# 3       dae_122      4.63964             HALLMARK_ESTROGEN_RESPONSE_LATE
# 2       dae_122      4.64101                  HALLMARK_KRAS_SIGNALING_DN
# 53        dae_7      5.68651                     HALLMARK_MYC_TARGETS_V1
# 54        dae_7      5.32922            HALLMARK_TNFA_SIGNALING_VIA_NFKB
# 56        dae_7      4.70884                        HALLMARK_E2F_TARGETS
# 58        dae_7      3.94306                     HALLMARK_G2M_CHECKPOINT
# 59        dae_7      3.93764                        HALLMARK_COAGULATION
# 57        dae_7      4.58541            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 55        dae_7      4.90257          HALLMARK_OXIDATIVE_PHOSPHORYLATION
# 52        dae_7      8.89840  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 51        dae_7      9.66454             HALLMARK_ESTROGEN_RESPONSE_LATE
# 50        dae_7     11.05460                         HALLMARK_MYOGENESIS
# ..          ...          ...                                         ...
# 14      dae_130      4.19995          HALLMARK_OXIDATIVE_PHOSPHORYLATION
# 18      dae_130      3.18336          HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# 19      dae_130      3.12972                        HALLMARK_E2F_TARGETS
# 17      dae_130      3.24741                HALLMARK_PANCREAS_BETA_CELLS
# 16      dae_130      3.30289             HALLMARK_ESTROGEN_RESPONSE_LATE
# 15      dae_130      4.14665                  HALLMARK_KRAS_SIGNALING_UP
# 13      dae_130      4.61725            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 12      dae_130      5.54803                    HALLMARK_APICAL_JUNCTION
# 11      dae_130      5.61845                         HALLMARK_MYOGENESIS
# 10      dae_130      9.04101  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 32       dae_24      4.53061          HALLMARK_INTERFERON_GAMMA_RESPONSE
# 33       dae_24      3.79301  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 34       dae_24      3.45501              HALLMARK_INFLAMMATORY_RESPONSE
# 36       dae_24      3.14545                       HALLMARK_ANGIOGENESIS
# 38       dae_24      2.90479                          HALLMARK_APOPTOSIS
# 39       dae_24      2.79638          HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# 37       dae_24      3.00637               HALLMARK_BILE_ACID_METABOLISM
# 35       dae_24      3.25582                         HALLMARK_PEROXISOME
# 31       dae_24      4.98350              HALLMARK_FATTY_ACID_METABOLISM
# 30       dae_24      6.65545                  HALLMARK_KRAS_SIGNALING_DN
# 41       dae_46      4.03099          HALLMARK_INTERFERON_ALPHA_RESPONSE
# 42       dae_46      3.45445          HALLMARK_INTERFERON_GAMMA_RESPONSE
# 44       dae_46      3.35291                          HALLMARK_APOPTOSIS
# 46       dae_46      3.06141                        HALLMARK_COAGULATION
# 49       dae_46      2.80768                  HALLMARK_KRAS_SIGNALING_DN
# 48       dae_46      2.97815                     HALLMARK_MYC_TARGETS_V1
# 47       dae_46      3.03802                            HALLMARK_HYPOXIA
# 45       dae_46      3.20800                     HALLMARK_UV_RESPONSE_DN
# 43       dae_46      3.40707          HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# 40       dae_46      7.15103          HALLMARK_OXIDATIVE_PHOSPHORYLATION
#
#         value   z_score algorithm    z    seed   weight      abs  z_dim  gene
# 21   1.465570   4.48129       dae  200  908341  0.23558  0.23558    200  TP53
# 24   1.952970   3.16951       dae  200  908341  0.23558  0.23558    200  TP53
# 25   0.569345   3.08817       dae  200  908341  0.23558  0.23558    200  TP53
# 27   1.273850   2.90375       dae  200  908341  0.23558  0.23558    200  TP53
# 28   0.828225   2.77715       dae  200  908341  0.23558  0.23558    200  TP53
# 29  -1.659480  -2.76895       dae  200  908341  0.23558  0.23558    200  TP53
# 26  -1.667030  -3.04312       dae  200  908341  0.23558  0.23558    200  TP53
# 23  -1.425400  -3.64827       dae  200  908341  0.23558  0.23558    200  TP53
# 22  -1.470770  -4.11478       dae  200  908341  0.23558  0.23558    200  TP53
# 20  -2.637230  -4.92812       dae  200  908341  0.23558  0.23558    200  TP53
# 0    5.530910   7.87064       dae  200  908341  0.19832  0.19832    200  TP53
# 1    3.602640   4.96567       dae  200  908341  0.19832  0.19832    200  TP53
# 4    4.266150   4.46584       dae  200  908341  0.19832  0.19832    200  TP53
# 5    3.216170   4.22858       dae  200  908341  0.19832  0.19832    200  TP53
# 9    2.827710   3.15448       dae  200  908341  0.19832  0.19832    200  TP53
# 8   -0.722036  -3.29913       dae  200  908341  0.19832  0.19832    200  TP53
# 7   -1.872320  -3.38226       dae  200  908341  0.19832  0.19832    200  TP53
# 6   -0.574795  -3.42185       dae  200  908341  0.19832  0.19832    200  TP53
# 3   -1.169420  -4.63964       dae  200  908341  0.19832  0.19832    200  TP53
# 2   -1.288630  -4.64101       dae  200  908341  0.19832  0.19832    200  TP53
# 53   3.340750   5.68651       dae  200  908341  0.16581  0.16581    200  TP53
# 54   1.933210   5.32922       dae  200  908341  0.16581  0.16581    200  TP53
# 56   2.443230   4.70884       dae  200  908341  0.16581  0.16581    200  TP53
# 58   2.011340   3.94306       dae  200  908341  0.16581  0.16581    200  TP53
# 59  -2.851220  -3.93764       dae  200  908341  0.16581  0.16581    200  TP53
# 57  -2.964680  -4.58541       dae  200  908341  0.16581  0.16581    200  TP53
# 55  -3.289700  -4.90257       dae  200  908341  0.16581  0.16581    200  TP53
# 52  -5.621630  -8.89840       dae  200  908341  0.16581  0.16581    200  TP53
# 51  -4.465240  -9.66454       dae  200  908341  0.16581  0.16581    200  TP53
# 50  -6.158190 -11.05460       dae  200  908341  0.16581  0.16581    200  TP53
# ..        ...       ...       ...  ...     ...      ...      ...    ...   ...
# 14   0.536709   4.19995       dae  200  908341 -0.16391  0.16391    200  TP53
# 18   0.486730   3.18336       dae  200  908341 -0.16391  0.16391    200  TP53
# 19  -0.658366   3.12972       dae  200  908341 -0.16391  0.16391    200  TP53
# 17  -1.533370  -3.24741       dae  200  908341 -0.16391  0.16391    200  TP53
# 16  -6.903760  -3.30289       dae  200  908341 -0.16391  0.16391    200  TP53
# 15  -6.125100  -4.14665       dae  200  908341 -0.16391  0.16391    200  TP53
# 13  -5.984540  -4.61725       dae  200  908341 -0.16391  0.16391    200  TP53
# 12  -7.965150  -5.54803       dae  200  908341 -0.16391  0.16391    200  TP53
# 11 -10.024900  -5.61845       dae  200  908341 -0.16391  0.16391    200  TP53
# 10 -11.344300  -9.04101       dae  200  908341 -0.16391  0.16391    200  TP53
# 32   2.830160   4.53061       dae  200  908341 -0.18192  0.18192    200  TP53
# 33   2.488630   3.79301       dae  200  908341 -0.18192  0.18192    200  TP53
# 34   2.166770   3.45501       dae  200  908341 -0.18192  0.18192    200  TP53
# 36   0.827268   3.14545       dae  200  908341 -0.18192  0.18192    200  TP53
# 38   1.879240   2.90479       dae  200  908341 -0.18192  0.18192    200  TP53
# 39   1.332590   2.79638       dae  200  908341 -0.18192  0.18192    200  TP53
# 37  -0.597128  -3.00637       dae  200  908341 -0.18192  0.18192    200  TP53
# 35  -1.020010  -3.25582       dae  200  908341 -0.18192  0.18192    200  TP53
# 31  -2.455750  -4.98350       dae  200  908341 -0.18192  0.18192    200  TP53
# 30  -2.611530  -6.65545       dae  200  908341 -0.18192  0.18192    200  TP53
# 41   2.274720   4.03099       dae  200  908341 -0.22864  0.22864    200  TP53
# 42   2.840930   3.45445       dae  200  908341 -0.22864  0.22864    200  TP53
# 44   1.014110   3.35291       dae  200  908341 -0.22864  0.22864    200  TP53
# 46   1.768820   3.06141       dae  200  908341 -0.22864  0.22864    200  TP53
# 49  -1.385910  -2.80768       dae  200  908341 -0.22864  0.22864    200  TP53
# 48  -1.470760  -2.97815       dae  200  908341 -0.22864  0.22864    200  TP53
# 47  -1.796630  -3.03802       dae  200  908341 -0.22864  0.22864    200  TP53
# 45  -1.280420  -3.20800       dae  200  908341 -0.22864  0.22864    200  TP53
# 43  -1.859830  -3.40707       dae  200  908341 -0.22864  0.22864    200  TP53
# 40  -3.154480  -7.15103       dae  200  908341 -0.22864  0.22864    200  TP53
#
# [70 rows x 12 columns]

# %%
# Output biobombe scores applied to high scoring DAE features
file = os.path.join('results', 'tcga_tp53_classify_top_biobombe_scores_dae_table.tsv')
top_biobombe_df.to_csv(file, sep='\t', index=False)
