# %% [markdown]
# ## Generating a Table of the BioBombe Interpreted Features in a High Scoring Ensemble model of TP53 inactivation
#
# **Gregory Way, 2019**
#
# I use the model previously identified that was used to predict TP53 inactivation.
# I observe the BioBombe gene set enrichment scores for the features with high coefficients in this model.

# %%
import os
import sys
import pandas as pd

# %% [markdown]
# ## Load the Top Model Identified Previously

# %%
model_file = os.path.join("results", "top_model_ensemble_tp53_feature_for_followup.tsv")
top_model_df = pd.read_table(model_file)
top_model_df
# Out:
#    gene  signal  z_dim      seed       algorithm  weight  num_features  \
# 0  TP53  signal    200  ensemble  Model Ensemble     906          1022
#
#    percent_zero    auroc   aupr data_type   grouping_  auroc_raw  aupr_raw  \
# 0      0.886497  0.90534  0.875        cv  TP53signal    0.91836   0.88467
#
#   z_dim_shape
# 0     z >= 20

# %%
# The seed we used to compile single model
seed = "165158"
z_dim = top_model_df.z_dim.values[0]

# %% [markdown]
# ## Load the BioBombe network projection results for Cancer Hallmarks

# %%
file = os.path.join("..", "6.biobombe-projection", "results", "tcga",
                    "gph", "signal", "tcga_z_200_GpH__geneset_scores.tsv.gz")

scores_df = (
    pd
    .read_table(file)
    .query("seed == @seed")
    .query("z == @z_dim")
)

scores_df = (
    scores_df
    .assign(full_feature=scores_df.algorithm.astype(str) + "_" + scores_df.feature.astype(str),
            abs_z_score=scores_df.z_score.abs())
)
scores_df.head()
# Out:
#    model_type                                    variable      value  z_score  \
# 8        real          HALLMARK_OXIDATIVE_PHOSPHORYLATION  -0.260304 -21.8954
# 20       real                     HALLMARK_MYC_TARGETS_V1  -1.547170 -19.3482
# 29       real            HALLMARK_TNFA_SIGNALING_VIA_NFKB -18.515600 -18.7641
# 30       real  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  -5.493200 -18.4886
# 31       real  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  -4.009360 -18.0103
#
#    algorithm  feature    z    seed full_feature  abs_z_score
# 8        ica       59  200  165158       ica_59      21.8954
# 20       pca        7  200  165158        pca_7      19.3482
# 29       dae      114  200  165158      dae_114      18.7641
# 30       vae      197  200  165158      vae_197      18.4886
# 31       vae      179  200  165158      vae_179      18.0103

# %% [markdown]
# ## Load Model Coefficients

# %%
file = os.path.join("results",
                    "mutation_ensemble",
                    "TP53",
                    "TP53_ensemble_all_alg_coefficients.tsv.gz")

top_n_features = 10

coef_df = (
    pd.read_table(file)
    .query("seed == @seed")
    .query("z_dim == @z_dim")
    .query("signal == 'signal'")
    .sort_values(by='abs', ascending=False)
    .head(top_n_features)
    .reset_index(drop=True)
)

# Rename columns
coef_extract_df = (
    pd.DataFrame(coef_df.feature.str.split('_').values.tolist(),
                 columns=['feature_alg', 'feature_num',
                          'feature_seed', 'feature_z',
                          'feature_signal'])
)

coef_extract_df = (
    coef_extract_df
    .assign(use_feature=coef_extract_df.feature_alg + "_" + coef_extract_df.feature_num)
)

coef_df = pd.concat([coef_df, coef_extract_df], axis='columns')

use_features = coef_df.use_feature.tolist()
coef_df
# Out:
#                      feature    weight       abs  signal  z_dim    seed  \
# 0  ica_191_165158_200_signal -0.167810  0.167810  signal    200  165158
# 1  dae_126_165158_200_signal  0.167490  0.167490  signal    200  165158
# 2   pca_32_165158_200_signal  0.159680  0.159680  signal    200  165158
# 3   pca_23_165158_200_signal  0.144620  0.144620  signal    200  165158
# 4  vae_172_165158_200_signal -0.123110  0.123110  signal    200  165158
# 5  vae_136_165158_200_signal -0.110750  0.110750  signal    200  165158
# 6   pca_99_165158_200_signal  0.109790  0.109790  signal    200  165158
# 7   nmf_97_165158_200_signal -0.107140  0.107140  signal    200  165158
# 8    dae_7_165158_200_signal  0.102290  0.102290  signal    200  165158
# 9   vae_18_165158_200_signal -0.099937  0.099937  signal    200  165158
#
#       algorithm  gene feature_alg feature_num feature_seed feature_z  \
# 0  all_ensemble  TP53         ica         191       165158       200
# 1  all_ensemble  TP53         dae         126       165158       200
# 2  all_ensemble  TP53         pca          32       165158       200
# 3  all_ensemble  TP53         pca          23       165158       200
# 4  all_ensemble  TP53         vae         172       165158       200
# 5  all_ensemble  TP53         vae         136       165158       200
# 6  all_ensemble  TP53         pca          99       165158       200
# 7  all_ensemble  TP53         nmf          97       165158       200
# 8  all_ensemble  TP53         dae           7       165158       200
# 9  all_ensemble  TP53         vae          18       165158       200
#
#   feature_signal use_feature
# 0         signal     ica_191
# 1         signal     dae_126
# 2         signal      pca_32
# 3         signal      pca_23
# 4         signal     vae_172
# 5         signal     vae_136
# 6         signal      pca_99
# 7         signal      nmf_97
# 8         signal       dae_7
# 9         signal      vae_18

# %%
# Explore the biobombe scores for specific DAE features
top_n_features = 10

biobombe_df = (
    scores_df
    .query("full_feature in @use_features")
    .merge(coef_df,
           how='left',
           left_on=['full_feature', 'algorithm', 'seed'],
           right_on=['use_feature', 'feature_alg', 'seed'])
    .drop(['model_type', 'feature_x', 'feature_y', 'signal'], axis='columns')
    .sort_values(by=['abs', 'abs_z_score'], ascending=False)
    .reset_index(drop=True)
)

top_biobombe_df = (
    biobombe_df
    .groupby('full_feature')
    .apply(func=lambda x: x.abs_z_score.nlargest(top_n_features))
    .reset_index()
    .merge(biobombe_df
           .reset_index(),
           right_on=['index', 'abs_z_score', 'full_feature'],
           left_on=['level_1', 'abs_z_score', 'full_feature'])
    .drop(['level_1', 'index'], axis='columns')
    .sort_values(by=['weight', 'z_score'], ascending=False)
)
    
    
print(top_biobombe_df.shape)
top_biobombe_df
# Out:
# (100, 19)
#    full_feature  abs_z_score                                    variable  \
# 0       dae_126      9.58473                     HALLMARK_MYC_TARGETS_V1
# 1       dae_126      5.68817                   HALLMARK_MTORC1_SIGNALING
# 2       dae_126      4.99144  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 5       dae_126      3.48989                        HALLMARK_COAGULATION
# 8       dae_126      3.08240                         HALLMARK_GLYCOLYSIS
# 9       dae_126      3.07642         HALLMARK_WNT_BETA_CATENIN_SIGNALING
# 7       dae_126      3.30858                        HALLMARK_P53_PATHWAY
# 6       dae_126      3.43755            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 4       dae_126      3.65614              HALLMARK_XENOBIOTIC_METABOLISM
# 3       dae_126      4.86171                HALLMARK_ALLOGRAFT_REJECTION
# 54       pca_32      4.38090                     HALLMARK_UV_RESPONSE_DN
# 55       pca_32      4.08463                  HALLMARK_PROTEIN_SECRETION
# 56       pca_32      4.01391            HALLMARK_PI3K_AKT_MTOR_SIGNALING
# 57       pca_32      3.73613                    HALLMARK_HEME_METABOLISM
# 58       pca_32      3.56838                    HALLMARK_MITOTIC_SPINDLE
# 59       pca_32      3.21159    HALLMARK_REACTIVE_OXIGEN_SPECIES_PATHWAY
# 53       pca_32      5.16025                     HALLMARK_MYC_TARGETS_V2
# 52       pca_32      5.34989          HALLMARK_INTERFERON_ALPHA_RESPONSE
# 51       pca_32      6.02572            HALLMARK_TNFA_SIGNALING_VIA_NFKB
# 50       pca_32      6.20246            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 40       pca_23     22.87420          HALLMARK_INTERFERON_ALPHA_RESPONSE
# 41       pca_23     16.37870          HALLMARK_INTERFERON_GAMMA_RESPONSE
# 46       pca_23      3.16667          HALLMARK_OXIDATIVE_PHOSPHORYLATION
# 49       pca_23      2.74127              HALLMARK_FATTY_ACID_METABOLISM
# 48       pca_23      3.00524                  HALLMARK_KRAS_SIGNALING_UP
# 47       pca_23      3.14087  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 45       pca_23      3.37869                        HALLMARK_COAGULATION
# 44       pca_23      3.56646            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 43       pca_23      5.25693              HALLMARK_XENOBIOTIC_METABOLISM
# 42       pca_23      6.18471             HALLMARK_ESTROGEN_RESPONSE_LATE
# ..          ...          ...                                         ...
# 70      vae_136      7.70741                  HALLMARK_ANDROGEN_RESPONSE
# 71      vae_136      4.80894            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 77      vae_136      3.05612                            HALLMARK_HYPOXIA
# 79      vae_136      2.56551                    HALLMARK_SPERMATOGENESIS
# 78      vae_136      2.85802                     HALLMARK_UV_RESPONSE_UP
# 76      vae_136      3.09656                    HALLMARK_APICAL_JUNCTION
# 75      vae_136      3.47886                         HALLMARK_COMPLEMENT
# 74      vae_136      3.72639                        HALLMARK_P53_PATHWAY
# 73      vae_136      4.01183                     HALLMARK_MYC_TARGETS_V1
# 72      vae_136      4.53069                  HALLMARK_KRAS_SIGNALING_UP
# 80      vae_172     16.60120          HALLMARK_OXIDATIVE_PHOSPHORYLATION
# 81      vae_172      8.27239                    HALLMARK_SPERMATOGENESIS
# 84      vae_172      6.48599                       HALLMARK_ADIPOGENESIS
# 88      vae_172      4.32057            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 89      vae_172      3.73761                         HALLMARK_MYOGENESIS
# 87      vae_172      4.37605              HALLMARK_INFLAMMATORY_RESPONSE
# 86      vae_172      4.64890                    HALLMARK_APICAL_JUNCTION
# 85      vae_172      5.52484            HALLMARK_TNFA_SIGNALING_VIA_NFKB
# 83      vae_172      6.84449  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 82      vae_172      7.02513                  HALLMARK_KRAS_SIGNALING_UP
# 22      ica_191      3.51463                            HALLMARK_HYPOXIA
# 23      ica_191      2.75656            HALLMARK_CHOLESTEROL_HOMEOSTASIS
# 24      ica_191      2.26821            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 25      ica_191      2.10101                     HALLMARK_UV_RESPONSE_UP
# 27      ica_191      1.92336                        HALLMARK_E2F_TARGETS
# 29      ica_191      1.69124                         HALLMARK_PEROXISOME
# 28      ica_191      1.84218          HALLMARK_INTERFERON_ALPHA_RESPONSE
# 26      ica_191      1.93814         HALLMARK_WNT_BETA_CATENIN_SIGNALING
# 21      ica_191      3.86375                 HALLMARK_TGF_BETA_SIGNALING
# 20      ica_191      4.79731                    HALLMARK_MITOTIC_SPINDLE
#
#        value   z_score algorithm_x    z    seed   weight      abs  z_dim  \
# 0   3.797060   9.58473         dae  200  165158  0.16749  0.16749    200
# 1   3.365900   5.68817         dae  200  165158  0.16749  0.16749    200
# 2   4.776580   4.99144         dae  200  165158  0.16749  0.16749    200
# 5   2.101940   3.48989         dae  200  165158  0.16749  0.16749    200
# 8   3.331440   3.08240         dae  200  165158  0.16749  0.16749    200
# 9  -0.432020  -3.07642         dae  200  165158  0.16749  0.16749    200
# 7  -1.755170  -3.30858         dae  200  165158  0.16749  0.16749    200
# 6  -1.173030  -3.43755         dae  200  165158  0.16749  0.16749    200
# 4  -1.648150  -3.65614         dae  200  165158  0.16749  0.16749    200
# 3   0.007916  -4.86171         dae  200  165158  0.16749  0.16749    200
# 54  0.256009   4.38090         pca  200  165158  0.15968  0.15968    200
# 55  0.355377   4.08463         pca  200  165158  0.15968  0.15968    200
# 56  0.400697   4.01391         pca  200  165158  0.15968  0.15968    200
# 57  0.472199   3.73613         pca  200  165158  0.15968  0.15968    200
# 58  0.513452   3.56838         pca  200  165158  0.15968  0.15968    200
# 59 -0.113939  -3.21159         pca  200  165158  0.15968  0.15968    200
# 53 -0.382438  -5.16025         pca  200  165158  0.15968  0.15968    200
# 52 -0.336033  -5.34989         pca  200  165158  0.15968  0.15968    200
# 51 -0.692720  -6.02572         pca  200  165158  0.15968  0.15968    200
# 50 -0.548228  -6.20246         pca  200  165158  0.15968  0.15968    200
# 40  1.898330  22.87420         pca  200  165158  0.14462  0.14462    200
# 41  2.267580  16.37870         pca  200  165158  0.14462  0.14462    200
# 46  0.640001   3.16667         pca  200  165158  0.14462  0.14462    200
# 49 -0.151430  -2.74127         pca  200  165158  0.14462  0.14462    200
# 48 -0.247502  -3.00524         pca  200  165158  0.14462  0.14462    200
# 47 -0.348693  -3.14087         pca  200  165158  0.14462  0.14462    200
# 45 -0.174877  -3.37869         pca  200  165158  0.14462  0.14462    200
# 44 -0.179935  -3.56646         pca  200  165158  0.14462  0.14462    200
# 43 -0.387059  -5.25693         pca  200  165158  0.14462  0.14462    200
# 42 -0.132130  -6.18471         pca  200  165158  0.14462  0.14462    200
# ..       ...       ...         ...  ...     ...      ...      ...    ...
# 70  0.222331   7.70741         vae  200  165158 -0.11075  0.11075    200
# 71 -0.036081   4.80894         vae  200  165158 -0.11075  0.11075    200
# 77 -0.353998   3.05612         vae  200  165158 -0.11075  0.11075    200
# 79 -0.484430   2.56551         vae  200  165158 -0.11075  0.11075    200
# 78 -1.421780  -2.85802         vae  200  165158 -0.11075  0.11075    200
# 76 -2.287340  -3.09656         vae  200  165158 -0.11075  0.11075    200
# 75 -1.886880  -3.47886         vae  200  165158 -0.11075  0.11075    200
# 74 -2.122540  -3.72639         vae  200  165158 -0.11075  0.11075    200
# 73 -2.029500  -4.01183         vae  200  165158 -0.11075  0.11075    200
# 72 -2.280270  -4.53069         vae  200  165158 -0.11075  0.11075    200
# 80  0.594250  16.60120         vae  200  165158 -0.12311  0.12311    200
# 81 -0.343745   8.27239         vae  200  165158 -0.12311  0.12311    200
# 84 -0.591065   6.48599         vae  200  165158 -0.12311  0.12311    200
# 88 -0.695266   4.32057         vae  200  165158 -0.12311  0.12311    200
# 89 -2.343920  -3.73761         vae  200  165158 -0.12311  0.12311    200
# 87 -2.557950  -4.37605         vae  200  165158 -0.12311  0.12311    200
# 86 -2.598210  -4.64890         vae  200  165158 -0.12311  0.12311    200
# 85 -2.729950  -5.52484         vae  200  165158 -0.12311  0.12311    200
# 83 -3.404260  -6.84449         vae  200  165158 -0.12311  0.12311    200
# 82 -3.091690  -7.02513         vae  200  165158 -0.12311  0.12311    200
# 22  0.006035   3.51463         ica  200  165158 -0.16781  0.16781    200
# 23  0.004046   2.75656         ica  200  165158 -0.16781  0.16781    200
# 24  0.007193   2.26821         ica  200  165158 -0.16781  0.16781    200
# 25  0.003106   2.10101         ica  200  165158 -0.16781  0.16781    200
# 27  0.005312   1.92336         ica  200  165158 -0.16781  0.16781    200
# 29  0.001024   1.69124         ica  200  165158 -0.16781  0.16781    200
# 28 -0.005604  -1.84218         ica  200  165158 -0.16781  0.16781    200
# 26 -0.004215  -1.93814         ica  200  165158 -0.16781  0.16781    200
# 21 -0.005509  -3.86375         ica  200  165158 -0.16781  0.16781    200
# 20 -0.019569  -4.79731         ica  200  165158 -0.16781  0.16781    200
#
#      algorithm_y  gene feature_alg feature_num feature_seed feature_z  \
# 0   all_ensemble  TP53         dae         126       165158       200
# 1   all_ensemble  TP53         dae         126       165158       200
# 2   all_ensemble  TP53         dae         126       165158       200
# 5   all_ensemble  TP53         dae         126       165158       200
# 8   all_ensemble  TP53         dae         126       165158       200
# 9   all_ensemble  TP53         dae         126       165158       200
# 7   all_ensemble  TP53         dae         126       165158       200
# 6   all_ensemble  TP53         dae         126       165158       200
# 4   all_ensemble  TP53         dae         126       165158       200
# 3   all_ensemble  TP53         dae         126       165158       200
# 54  all_ensemble  TP53         pca          32       165158       200
# 55  all_ensemble  TP53         pca          32       165158       200
# 56  all_ensemble  TP53         pca          32       165158       200
# 57  all_ensemble  TP53         pca          32       165158       200
# 58  all_ensemble  TP53         pca          32       165158       200
# 59  all_ensemble  TP53         pca          32       165158       200
# 53  all_ensemble  TP53         pca          32       165158       200
# 52  all_ensemble  TP53         pca          32       165158       200
# 51  all_ensemble  TP53         pca          32       165158       200
# 50  all_ensemble  TP53         pca          32       165158       200
# 40  all_ensemble  TP53         pca          23       165158       200
# 41  all_ensemble  TP53         pca          23       165158       200
# 46  all_ensemble  TP53         pca          23       165158       200
# 49  all_ensemble  TP53         pca          23       165158       200
# 48  all_ensemble  TP53         pca          23       165158       200
# 47  all_ensemble  TP53         pca          23       165158       200
# 45  all_ensemble  TP53         pca          23       165158       200
# 44  all_ensemble  TP53         pca          23       165158       200
# 43  all_ensemble  TP53         pca          23       165158       200
# 42  all_ensemble  TP53         pca          23       165158       200
# ..           ...   ...         ...         ...          ...       ...
# 70  all_ensemble  TP53         vae         136       165158       200
# 71  all_ensemble  TP53         vae         136       165158       200
# 77  all_ensemble  TP53         vae         136       165158       200
# 79  all_ensemble  TP53         vae         136       165158       200
# 78  all_ensemble  TP53         vae         136       165158       200
# 76  all_ensemble  TP53         vae         136       165158       200
# 75  all_ensemble  TP53         vae         136       165158       200
# 74  all_ensemble  TP53         vae         136       165158       200
# 73  all_ensemble  TP53         vae         136       165158       200
# 72  all_ensemble  TP53         vae         136       165158       200
# 80  all_ensemble  TP53         vae         172       165158       200
# 81  all_ensemble  TP53         vae         172       165158       200
# 84  all_ensemble  TP53         vae         172       165158       200
# 88  all_ensemble  TP53         vae         172       165158       200
# 89  all_ensemble  TP53         vae         172       165158       200
# 87  all_ensemble  TP53         vae         172       165158       200
# 86  all_ensemble  TP53         vae         172       165158       200
# 85  all_ensemble  TP53         vae         172       165158       200
# 83  all_ensemble  TP53         vae         172       165158       200
# 82  all_ensemble  TP53         vae         172       165158       200
# 22  all_ensemble  TP53         ica         191       165158       200
# 23  all_ensemble  TP53         ica         191       165158       200
# 24  all_ensemble  TP53         ica         191       165158       200
# 25  all_ensemble  TP53         ica         191       165158       200
# 27  all_ensemble  TP53         ica         191       165158       200
# 29  all_ensemble  TP53         ica         191       165158       200
# 28  all_ensemble  TP53         ica         191       165158       200
# 26  all_ensemble  TP53         ica         191       165158       200
# 21  all_ensemble  TP53         ica         191       165158       200
# 20  all_ensemble  TP53         ica         191       165158       200
#
#    feature_signal use_feature
# 0          signal     dae_126
# 1          signal     dae_126
# 2          signal     dae_126
# 5          signal     dae_126
# 8          signal     dae_126
# 9          signal     dae_126
# 7          signal     dae_126
# 6          signal     dae_126
# 4          signal     dae_126
# 3          signal     dae_126
# 54         signal      pca_32
# 55         signal      pca_32
# 56         signal      pca_32
# 57         signal      pca_32
# 58         signal      pca_32
# 59         signal      pca_32
# 53         signal      pca_32
# 52         signal      pca_32
# 51         signal      pca_32
# 50         signal      pca_32
# 40         signal      pca_23
# 41         signal      pca_23
# 46         signal      pca_23
# 49         signal      pca_23
# 48         signal      pca_23
# 47         signal      pca_23
# 45         signal      pca_23
# 44         signal      pca_23
# 43         signal      pca_23
# 42         signal      pca_23
# ..            ...         ...
# 70         signal     vae_136
# 71         signal     vae_136
# 77         signal     vae_136
# 79         signal     vae_136
# 78         signal     vae_136
# 76         signal     vae_136
# 75         signal     vae_136
# 74         signal     vae_136
# 73         signal     vae_136
# 72         signal     vae_136
# 80         signal     vae_172
# 81         signal     vae_172
# 84         signal     vae_172
# 88         signal     vae_172
# 89         signal     vae_172
# 87         signal     vae_172
# 86         signal     vae_172
# 85         signal     vae_172
# 83         signal     vae_172
# 82         signal     vae_172
# 22         signal     ica_191
# 23         signal     ica_191
# 24         signal     ica_191
# 25         signal     ica_191
# 27         signal     ica_191
# 29         signal     ica_191
# 28         signal     ica_191
# 26         signal     ica_191
# 21         signal     ica_191
# 20         signal     ica_191
#
# [100 rows x 19 columns]

# %%
# Output biobombe scores applied to high scoring DAE features
file = os.path.join('results', 'tcga_tp53_classify_top_biobombe_scores_ensemble_model_table.tsv')
top_biobombe_df.to_csv(file, sep='\t', index=False)
