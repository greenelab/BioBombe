# %% [markdown]
# # Visualizing Separation Analysis
#
# **Gregory Way 2019**
#
# Visualizing GTEx Sex and TARGET MYCN Status Features

# %%
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(cowplot))

# %%
# Store t test results and identify top features
t_test_results_files <- list.files("results", full.names = TRUE)
t_test_results_files <- t_test_results_files[grepl('t_test', t_test_results_files)]
t_test_results_files
# Out:
# [1] "results/nbl_mycn_separation_target_t_test.tsv"
# [2] "results/sex_separation_gtex_t_test.tsv"
# [3] "results/sex_separation_tcga_t_test.tsv"

# %%
# Store t test results and identify top features
best_result_list <- list()
line_gg_list <- list()
for (t_test_file in t_test_results_files) {
  full_results_df <- readr::read_tsv(t_test_file,
                                     col_types = readr::cols(
                                       t_stat = readr::col_double(),
                                       t_p = readr::col_double(),
                                       algorithm = readr::col_character(),
                                       feature_num = readr::col_double(),
                                       z_dim = readr::col_double(),
                                       signal = readr::col_character(),
                                       seed = readr::col_double(),
                                       neg_log_p = readr::col_double()
                                       )
                                     )
  
  top_results_df <- full_results_df %>%
    dplyr::group_by(algorithm, z_dim, signal) %>%
    dplyr::filter(neg_log_p == max(neg_log_p),
                  signal == "signal")
  
  # Create factors for plotting
  top_results_df$z_dim <-
    factor(top_results_df$z_dim,
           levels =
             sort(as.numeric(paste(unique(top_results_df$z_dim))))
    )
  
  top_results_df$algorithm <-
    factor(top_results_df$algorithm,
           levels = c("pca", "ica", "nmf", "dae", "vae"))
  
  panel_gg <- ggplot(top_results_df,
                       aes(x = z_dim,
                           y = neg_log_p,
                           color = algorithm,
                           group = algorithm)) +
    geom_smooth(aes(fill = algorithm),
                lwd = 0.3,
                alpha = 0.4,
                method = 'loess',
                formula = 'y ~ x') +
    geom_point(size = 0.5) +
    scale_color_manual(name = "Algorithm",
                       values = c("#e41a1c",
                                  "#377eb8",
                                  "#4daf4a",
                                  "#984ea3",
                                  "#ff7f00"),
                       labels = c("pca" = "PCA",
                                  "ica" = "ICA",
                                  "nmf" = "NMF",
                                  "dae" = "DAE",
                                  "vae" = "VAE")) +
    scale_fill_manual(name = "Algorithm",
                      values = c("#e41a1c",
                                 "#377eb8",
                                 "#4daf4a",
                                 "#984ea3",
                                 "#ff7f00"),
                      labels = c("pca" = "PCA",
                                 "ica" = "ICA",
                                 "nmf" = "NMF",
                                 "dae" = "DAE",
                                 "vae" = "VAE")) +
    theme_bw() +
    ylab("-log10 P Value") +
    xlab("k Dimensions") +
    theme(axis.title.x = element_text(size = 7),
          axis.title.y = element_text(size = 7),
          axis.text.x = element_text(angle = 90,
                                     size = 5),
          axis.text.y = element_text(size = 6),
          plot.title = element_text(size = 8,
                                    hjust = 0.5),
          legend.text = element_text(size = 5),
          legend.title = element_text(size = 6),
          legend.key.size = unit(0.4, "lines"))
  
  
  best_result_df <- top_results_df %>%
    dplyr::arrange(desc(neg_log_p)) %>%
    dplyr::ungroup() %>%
    dplyr::top_n(n = 1, wt = neg_log_p)
  
  best_result_list[[t_test_file]] <- best_result_df
  line_gg_list[[t_test_file]] <- panel_gg
}

# %% [markdown]
# ## Plot GTEx Sex Example

# %%
file <- file.path("..", "0.expression-download", "download", "GTEx_v7_Annotations_SubjectPhenotypesDS.txt")
gtex_pheno_df <- readr::read_tsv(file)
# Out:
# Parsed with column specification:
# cols(
#   SUBJID = col_character(),
#   SEX = col_integer(),
#   AGE = col_character(),
#   DTHHRDY = col_integer()
# )

# %%
best_k_dim <- paste(best_result_list[[t_test_results_files[2]]]$z_dim)
best_seed <- paste(best_result_list[[t_test_results_files[2]]]$seed)
best_feature <- paste0(paste(best_result_list[[t_test_results_files[2]]]$algorithm),
                       "_", 
                       paste(best_result_list[[t_test_results_files[2]]]$feature_num))

# %%
print(best_k_dim)
print(best_seed)
print(best_feature)
# Out:
# [1] "200"
# [1] "486191"
# [1] "vae_108"

# %%
feature_file <- file.path("..",
                          "2.sequential-compression",
                          "results",
                          "GTEX_results",
                          "ensemble_z_matrices",
                          paste0("gtex_components_", best_k_dim),
                          paste0("model_", best_seed, "_z_matrix.tsv.gz"))

top_feature_df <- readr::read_tsv(feature_file,
                                  col_types = readr::cols(
                                    .default = readr::col_double(),
                                    sample_id = readr::col_character()
                                  )
) %>%
  dplyr::select(sample_id, !!best_feature)

# %%
full_gtex_ids <- c()
for (gtex_id in strsplit(top_feature_df$sample_id, "-")) {
  gtex_id_unlist <- unlist(gtex_id)
  sample_id <- paste0(gtex_id_unlist[1], "-", gtex_id_unlist[2])
  full_gtex_ids <- c(full_gtex_ids, sample_id)
}

top_feature_df$gtex_id <- full_gtex_ids
top_feature_df <- top_feature_df %>%
  dplyr::left_join(gtex_pheno_df, by = c("gtex_id" = "SUBJID"))

top_feature_df$SEX <- dplyr::recode_factor(top_feature_df$SEX, `1` = "Male", `2` = "Female")
top_feature_df$SEX <- factor(top_feature_df$SEX, levels = c("Female", "Male"))

# %%
gtex_sex_gg <- ggplot(top_feature_df,
                      aes(y = vae_108,
                          x = SEX,
                          fill = SEX)) +
  geom_boxplot(alpha = 0.5,
               outlier.alpha = 0) +
  geom_jitter(aes(color = SEX),
              size = 0.2,
              alpha = 0.2,
              width = 0.3) +
  scale_fill_manual(labels = c("Male" = "Male",
                               "Female" = "Female"),
                    values = c("Male" = "#42c8f4",
                               "Female" = "#f489c9")) +
  scale_color_manual(labels = c("Male" = "Male",
                                "Female" = "Female"),
                     values = c("Male" = "#42c8f4",
                                "Female" = "#f489c9")) +
  theme_bw() +
  ylab("VAE Feature 108 (k = 200)") +
  xlab("") +
  ggtitle("GTEx Sex") +
  theme(axis.title.x = element_text(size = 7),
        axis.title.y = element_text(size = 7),
        axis.text.x = element_text(size = 6),
        axis.text.y = element_text(size = 6),
        plot.title = element_text(size = 8,
                                  hjust = 0.5),
        legend.position = "none")

gtex_sex_gg
# Out:
# plot without title

# %% [markdown]
# ## Plot TCGA Sex Example

# %%
# Load TCGA phenotype data
file <- file.path("..", "0.expression-download", "download", "TCGA-CDR-SupplementalTableS1.xlsx")
tcga_pheno_df <- readxl::read_xlsx(file, sheet=1)

head(tcga_pheno_df)
# Out:
# Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1910 / R1910C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1911 / R1911C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1912 / R1912C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1913 / R1913C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1914 / R1914C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1915 / R1915C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1916 / R1916C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1917 / R1917C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1918 / R1918C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1919 / R1919C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1920 / R1920C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1921 / R1921C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1922 / R1922C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1923 / R1923C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1924 / R1924C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1925 / R1925C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1926 / R1926C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1927 / R1927C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1928 / R1928C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1929 / R1929C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1930 / R1930C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1931 / R1931C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1932 / R1932C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1933 / R1933C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1934 / R1934C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1935 / R1935C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1936 / R1936C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1937 / R1937C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1938 / R1938C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1939 / R1939C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1940 / R1940C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1941 / R1941C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1942 / R1942C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1943 / R1943C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1944 / R1944C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1945 / R1945C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1946 / R1946C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1947 / R1947C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1948 / R1948C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1949 / R1949C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1950 / R1950C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1951 / R1951C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1952 / R1952C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1953 / R1953C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y1954 / R1954C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5427 / R5427C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5428 / R5428C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5429 / R5429C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5430 / R5430C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5431 / R5431C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5432 / R5432C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5433 / R5433C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5434 / R5434C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5435 / R5435C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5436 / R5436C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5437 / R5437C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5438 / R5438C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5439 / R5439C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5440 / R5440C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5441 / R5441C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5442 / R5442C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5443 / R5443C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5444 / R5444C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5445 / R5445C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5446 / R5446C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5447 / R5447C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5448 / R5448C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5449 / R5449C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5450 / R5450C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5451 / R5451C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5452 / R5452C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5453 / R5453C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5454 / R5454C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5455 / R5455C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5456 / R5456C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5457 / R5457C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5458 / R5458C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5459 / R5459C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5460 / R5460C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5461 / R5461C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5462 / R5462C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5463 / R5463C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5464 / R5464C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5465 / R5465C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5466 / R5466C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5467 / R5467C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5468 / R5468C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5469 / R5469C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5470 / R5470C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5471 / R5471C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5472 / R5472C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5473 / R5473C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5474 / R5474C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5475 / R5475C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5476 / R5476C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5477 / R5477C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5478 / R5478C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5479 / R5479C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5480 / R5480C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5481 / R5481C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5482 / R5482C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5483 / R5483C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5484 / R5484C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5485 / R5485C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5486 / R5486C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5487 / R5487C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5488 / R5488C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5489 / R5489C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5490 / R5490C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5491 / R5491C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5492 / R5492C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5493 / R5493C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5494 / R5494C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5495 / R5495C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5496 / R5496C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5497 / R5497C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5498 / R5498C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5499 / R5499C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5500 / R5500C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5501 / R5501C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5502 / R5502C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5503 / R5503C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5504 / R5504C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5505 / R5505C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5506 / R5506C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5507 / R5507C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5508 / R5508C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5509 / R5509C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5510 / R5510C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5511 / R5511C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5512 / R5512C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5513 / R5513C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5514 / R5514C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5515 / R5515C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5516 / R5516C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5517 / R5517C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5518 / R5518C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5519 / R5519C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5520 / R5520C25: got 'R2'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5521 / R5521C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5522 / R5522C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5523 / R5523C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5524 / R5524C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5525 / R5525C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5526 / R5526C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5527 / R5527C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5528 / R5528C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5529 / R5529C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5530 / R5530C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5531 / R5531C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5532 / R5532C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5533 / R5533C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5534 / R5534C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5535 / R5535C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5536 / R5536C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5537 / R5537C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5538 / R5538C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5539 / R5539C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5540 / R5540C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5541 / R5541C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5542 / R5542C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5543 / R5543C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5544 / R5544C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5545 / R5545C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5546 / R5546C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5547 / R5547C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5548 / R5548C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5549 / R5549C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5550 / R5550C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5551 / R5551C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5552 / R5552C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5553 / R5553C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5554 / R5554C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5555 / R5555C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5556 / R5556C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5557 / R5557C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5558 / R5558C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5559 / R5559C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5560 / R5560C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5561 / R5561C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5562 / R5562C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5563 / R5563C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5564 / R5564C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5565 / R5565C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5566 / R5566C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5567 / R5567C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5568 / R5568C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5569 / R5569C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5570 / R5570C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5571 / R5571C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5572 / R5572C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5573 / R5573C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5574 / R5574C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5575 / R5575C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5576 / R5576C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5577 / R5577C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5578 / R5578C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5579 / R5579C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5580 / R5580C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5581 / R5581C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5582 / R5582C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5583 / R5583C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5584 / R5584C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5585 / R5585C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5586 / R5586C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5587 / R5587C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5588 / R5588C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5589 / R5589C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5590 / R5590C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5591 / R5591C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5592 / R5592C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5593 / R5593C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5594 / R5594C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5595 / R5595C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5596 / R5596C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5597 / R5597C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5598 / R5598C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5599 / R5599C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5600 / R5600C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5601 / R5601C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5602 / R5602C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5603 / R5603C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5604 / R5604C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5605 / R5605C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5606 / R5606C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5607 / R5607C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5608 / R5608C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5609 / R5609C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5610 / R5610C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5611 / R5611C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5612 / R5612C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5613 / R5613C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5614 / R5614C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5615 / R5615C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5616 / R5616C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5617 / R5617C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5618 / R5618C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5619 / R5619C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5620 / R5620C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5621 / R5621C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5622 / R5622C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5623 / R5623C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5624 / R5624C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5625 / R5625C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5626 / R5626C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5627 / R5627C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5628 / R5628C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5629 / R5629C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5630 / R5630C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5631 / R5631C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5632 / R5632C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5633 / R5633C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5634 / R5634C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5635 / R5635C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5636 / R5636C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5637 / R5637C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5638 / R5638C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5639 / R5639C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5640 / R5640C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5641 / R5641C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5642 / R5642C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5643 / R5643C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5644 / R5644C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5645 / R5645C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5646 / R5646C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5647 / R5647C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5648 / R5648C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5649 / R5649C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5650 / R5650C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5651 / R5651C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5652 / R5652C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5653 / R5653C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5654 / R5654C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5655 / R5655C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5656 / R5656C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5657 / R5657C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5658 / R5658C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5659 / R5659C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5660 / R5660C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5661 / R5661C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5662 / R5662C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5663 / R5663C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5664 / R5664C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5665 / R5665C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5666 / R5666C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5667 / R5667C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5668 / R5668C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5669 / R5669C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5670 / R5670C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5671 / R5671C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5672 / R5672C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5673 / R5673C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5674 / R5674C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5675 / R5675C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5676 / R5676C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5677 / R5677C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5678 / R5678C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5679 / R5679C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5680 / R5680C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5681 / R5681C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5682 / R5682C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5683 / R5683C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5684 / R5684C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5685 / R5685C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5686 / R5686C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5687 / R5687C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5688 / R5688C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5689 / R5689C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5690 / R5690C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5691 / R5691C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5692 / R5692C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5693 / R5693C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5694 / R5694C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5695 / R5695C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5696 / R5696C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5697 / R5697C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5698 / R5698C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5699 / R5699C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5700 / R5700C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5701 / R5701C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5702 / R5702C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5703 / R5703C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5704 / R5704C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5705 / R5705C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5706 / R5706C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5707 / R5707C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5708 / R5708C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5709 / R5709C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5710 / R5710C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5711 / R5711C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5712 / R5712C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5713 / R5713C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5714 / R5714C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5715 / R5715C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5716 / R5716C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5717 / R5717C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5718 / R5718C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5719 / R5719C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5720 / R5720C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5721 / R5721C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5722 / R5722C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5723 / R5723C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5724 / R5724C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y5725 / R5725C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# ...
# “Expecting logical in Y10254 / R10254C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10255 / R10255C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10256 / R10256C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10257 / R10257C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10258 / R10258C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10259 / R10259C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10260 / R10260C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10261 / R10261C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10262 / R10262C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10263 / R10263C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10264 / R10264C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10265 / R10265C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10266 / R10266C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10267 / R10267C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10268 / R10268C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10269 / R10269C25: got 'R2'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10270 / R10270C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10271 / R10271C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10272 / R10272C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10273 / R10273C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10274 / R10274C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10275 / R10275C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10276 / R10276C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10277 / R10277C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10278 / R10278C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10279 / R10279C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10280 / R10280C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10281 / R10281C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10282 / R10282C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10283 / R10283C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10284 / R10284C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10285 / R10285C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10286 / R10286C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10287 / R10287C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10288 / R10288C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10289 / R10289C25: got '[Unknown]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10290 / R10290C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10291 / R10291C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10292 / R10292C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10293 / R10293C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10294 / R10294C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10295 / R10295C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10296 / R10296C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10297 / R10297C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10298 / R10298C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10299 / R10299C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10300 / R10300C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10301 / R10301C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10302 / R10302C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10303 / R10303C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10304 / R10304C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10305 / R10305C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10306 / R10306C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10307 / R10307C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10308 / R10308C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10309 / R10309C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10310 / R10310C25: got '[Unknown]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10311 / R10311C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10312 / R10312C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10313 / R10313C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10314 / R10314C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10315 / R10315C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10316 / R10316C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10317 / R10317C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10318 / R10318C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10319 / R10319C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10320 / R10320C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10321 / R10321C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10322 / R10322C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10323 / R10323C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10324 / R10324C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10325 / R10325C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10326 / R10326C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10327 / R10327C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10328 / R10328C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10329 / R10329C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10330 / R10330C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10331 / R10331C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10332 / R10332C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10333 / R10333C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10334 / R10334C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10335 / R10335C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10336 / R10336C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10337 / R10337C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10338 / R10338C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10339 / R10339C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10340 / R10340C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10341 / R10341C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10342 / R10342C25: got 'RX'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10343 / R10343C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10344 / R10344C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10345 / R10345C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10346 / R10346C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10347 / R10347C25: got 'R1'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10348 / R10348C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10349 / R10349C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10350 / R10350C25: got 'R0'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10351 / R10351C25: got '[Not Available]'”Warning message in read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim, :
# “Expecting logical in Y10352 / R10352C25: got 'RX'”
#   X__1 bcr_patient_barcode type age_at_initial_pathologic_diagnosis gender
# 1 1    TCGA-OR-A5J1        ACC  58                                  MALE
# 2 2    TCGA-OR-A5J2        ACC  44                                  FEMALE
# 3 3    TCGA-OR-A5J3        ACC  23                                  FEMALE
# 4 4    TCGA-OR-A5J4        ACC  23                                  FEMALE
# 5 5    TCGA-OR-A5J5        ACC  30                                  MALE
# 6 6    TCGA-OR-A5J6        ACC  29                                  FEMALE
#   race                      ajcc_pathologic_tumor_stage clinical_stage
# 1 WHITE                     Stage II                    [Not Applicable]
# 2 WHITE                     Stage IV                    [Not Applicable]
# 3 WHITE                     Stage III                   [Not Applicable]
# 4 WHITE                     Stage IV                    [Not Applicable]
# 5 WHITE                     Stage III                   [Not Applicable]
# 6 BLACK OR AFRICAN AMERICAN Stage II                    [Not Applicable]
#   histological_type                    histological_grade ⋯ residual_tumor OS
# 1 Adrenocortical carcinoma- Usual Type [Not Available]    ⋯ NA             1
# 2 Adrenocortical carcinoma- Usual Type [Not Available]    ⋯ NA             1
# 3 Adrenocortical carcinoma- Usual Type [Not Available]    ⋯ NA             0
# 4 Adrenocortical carcinoma- Usual Type [Not Available]    ⋯ NA             1
# 5 Adrenocortical carcinoma- Usual Type [Not Available]    ⋯ NA             1
# 6 Adrenocortical carcinoma- Usual Type [Not Available]    ⋯ NA             0
#   OS.time DSS DSS.time DFI DFI.time PFI PFI.time Redaction
# 1 1355    1   1355      1   754     1    754     NA
# 2 1677    1   1677     NA    NA     1    289     NA
# 3 2091    0   2091      1    53     1     53     NA
# 4  423    1    423     NA    NA     1    126     NA
# 5  365    1    365     NA    NA     1     50     NA
# 6 2703    0   2703      0  2703     0   2703     NA

# %%
best_k_dim <- paste(best_result_list[[t_test_results_files[3]]]$z_dim)
best_seed <- paste(best_result_list[[t_test_results_files[3]]]$seed)
best_feature <- paste0(paste(best_result_list[[t_test_results_files[3]]]$algorithm),
                       "_", 
                       paste(best_result_list[[t_test_results_files[3]]]$feature_num))

# %%
print(best_k_dim)
print(best_seed)
print(best_feature)
# Out:
# [1] "20"
# [1] "486191"
# [1] "vae_16"

# %%
feature_file <- file.path("..",
                          "2.sequential-compression",
                          "results",
                          "TCGA_results",
                          "ensemble_z_matrices",
                          paste0("tcga_components_", best_k_dim),
                          paste0("model_", best_seed, "_z_matrix.tsv.gz"))

top_feature_df <- readr::read_tsv(feature_file,
                                  col_types = readr::cols(
                                    .default = readr::col_double(),
                                    sample_id = readr::col_character()
                                  )
) %>%
  dplyr::select(sample_id, !!best_feature)

head(top_feature_df)
# Out:
#   sample_id       vae_16
# 1 TCGA-LL-A73Z-01 9.030849
# 2 TCGA-55-8207-01 3.677592
# 3 TCGA-FF-A7CR-01 0.000000
# 4 TCGA-BK-A13C-11 3.482272
# 5 TCGA-EB-A6L9-06 1.880454
# 6 TCGA-D8-A145-01 9.052761

# %%
dim(top_feature_df)
# Out:
# [1] 9954    2

# %%
full_tcga_ids <- c()
for (tcga_id in strsplit(top_feature_df$sample_id, "-")) {
  tcga_id_unlist <- unlist(tcga_id)
  sample_id <- paste0(tcga_id_unlist[1], "-", tcga_id_unlist[2], "-", tcga_id_unlist[3])
  full_tcga_ids <- c(full_tcga_ids, sample_id)
}

top_feature_df$tcga_id <- full_tcga_ids
top_feature_df <- top_feature_df %>%
  dplyr::left_join(tcga_pheno_df, by = c("tcga_id" = "bcr_patient_barcode"))

top_feature_df$gender[is.na(top_feature_df$gender)] <- "Unlabeled"
top_feature_df$gender <- dplyr::recode_factor(top_feature_df$gender, "MALE" = "Male", "FEMALE" = "Female")
top_feature_df$gender <- factor(top_feature_df$gender, levels = c("Female", "Male", "Unlabeled"))

# %%
tcga_sex_gg <- ggplot(top_feature_df,
                      aes(y = vae_16,
                          x = gender,
                          fill = gender)) +
  geom_boxplot(alpha = 0.5,
               outlier.alpha = 0) +
  geom_jitter(aes(color = gender),
              size = 0.2,
              alpha = 0.2,
              width = 0.3) +
  scale_fill_manual(labels = c("Male" = "Male",
                               "Female" = "Female",
                               "Unlabeled" = "Unlabeled"),
                    values = c("Male" = "#42c8f4",
                               "Female" = "#f489c9",
                               "Unlabeled" = "grey25")) +
  scale_color_manual(labels = c("Male" = "Male",
                                "Female" = "Female",
                                "Unlabeled" = "Unlabeled"),
                     values = c("Male" = "#42c8f4",
                                "Female" = "#f489c9",
                                "Unlabeled" = "grey25")) +
  theme_bw() +
  ylab("VAE Feature 16 (k = 20)") +
  xlab("") +
  ggtitle("TCGA Sex") +
  theme(axis.title.x = element_text(size = 7),
        axis.title.y = element_text(size = 7),
        axis.text.x = element_text(size = 6),
        axis.text.y = element_text(size = 6),
        plot.title = element_text(size = 8,
                                  hjust = 0.5),
        legend.position = "none")

tcga_sex_gg
# Out:
# plot without title

# %% [markdown]
# ## Plot TARGET MYCN Amplification Results

# %%
best_k_dim <- paste(best_result_list[[t_test_results_files[1]]]$z_dim)
best_seed <- paste(best_result_list[[t_test_results_files[1]]]$seed)
best_feature <- paste0(paste(best_result_list[[t_test_results_files[1]]]$algorithm),
                       "_", 
                       paste(best_result_list[[t_test_results_files[1]]]$feature_num))

# %%
print(best_k_dim)
print(best_seed)
print(best_feature)
# Out:
# [1] "200"
# [1] "451283"
# [1] "vae_111"

# %%
feature_file <- file.path("..",
                          "2.sequential-compression",
                          "results",
                          "TARGET_results",
                          "ensemble_z_matrices",
                          paste0("target_components_", best_k_dim),
                          paste0("model_", best_seed, "_z_matrix.tsv.gz"))

top_feature_df <- readr::read_tsv(feature_file,
                                  col_types = readr::cols(
                                    .default = readr::col_double(),
                                    sample_id = readr::col_character()
                                    )
                                  ) %>%
  dplyr::select(sample_id, !!best_feature)

# %%
# Load TARGET phenotype data
file <- file.path("..", "0.expression-download", "data", "2017-09-30-TARGET update harmonized.txt")
nbl_pheno_df <- readr::read_tsv(file)

full_target_ids <- c()
for (target_id in strsplit(top_feature_df$sample_id, "-")) {
  target_id_unlist <- unlist(target_id)
  full_target_ids <- c(full_target_ids, target_id_unlist[3])
}

top_feature_df$target_id <- full_target_ids
top_feature_df <- top_feature_df %>% 
  dplyr::inner_join(nbl_pheno_df, by = c("target_id" = "usi"))
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   `Age at Diagnosis in Days` = col_integer(),
#   `Event Free Survival Time in Days` = col_integer(),
#   `Overall Survival Time in Days` = col_integer(),
#   `Year of Diagnosis` = col_integer(),
#   `Year of Last Follow Up` = col_integer(),
#   `Ploidy Value` = col_double()
# )
# See spec(...) for full column specifications.

# %%
mycn_amp_gg <- ggplot(top_feature_df,
                      aes(y = vae_111,
                          x = `MYCN status`,
                          fill = `MYCN status`)) +
  geom_boxplot(alpha = 0.5,
               outlier.alpha = 0) +
  geom_jitter(aes(color = `MYCN status`),
              alpha = 0.7,
              size = 0.9,
              width = 0.2) +
  scale_fill_manual(labels = c("Amplified" = "Amplified",
                               "Not Amplified" = "Not Amplified",
                               "Unknown" = "Unknown"),
                    values = c("Amplified" = "#d95f02",
                               "Not Amplified" = "#1b9e77",
                               "Unknown" = "grey25")) +
  scale_color_manual(labels = c("Amplified" = "Amplified",
                                "Not Amplified" = "Not Amplified",
                                "Unknown" = "Unknown"),
                     values = c("Amplified" = "#d95f02",
                                "Not Amplified" = "#1b9e77",
                                "Unknown" = "grey25")) +
  theme_bw() +
  ylab("VAE Feature 111 (k = 200)") +
  xlab("") +
  ggtitle("TARGET NBL MYCN Status") +
  theme(axis.title.x = element_text(size = 7),
       axis.title.y = element_text(size = 7),
       axis.text.x = element_text(size = 6),
       axis.text.y = element_text(size = 6),
       plot.title = element_text(size = 8,
                                 hjust = 0.5),
       legend.position = "none")

mycn_amp_gg
# Out:
# plot without title

# %% [markdown]
# ## Plot MYCN Signature Applied to NBL Cell Lines

# %%
file <- file.path("results", "mycn_nbl_scores.tsv")
mycn_validation_df <- readr::read_tsv(file)

mycn_validation_df$`MYCN status` <- dplyr::recode_factor(mycn_validation_df$`MYCN status`,
                                                         "Non-amplified" = "Not Amplified")
mycn_validation_df$`MYCN status` <- factor(mycn_validation_df$`MYCN status`,
                                           levels = c("Amplified", "Not Amplified"))
head(mycn_validation_df)
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   X1 = col_integer(),
#   vae_111 = col_double(),
#   `Cell Line` = col_character(),
#   `MYCN status` = col_character(),
#   `1p36 del` = col_character(),
#   `3p26 del` = col_character(),
#   `11q23 del` = col_character(),
#   `17q21-qter unbal gain` = col_character(),
#   `ALK mutation` = col_character(),
#   `p53 mutation` = col_character()
# )
#   X1 vae_111  Cell Line MYCN status
# 1 0  6.253521 CHP134    Amplified
# 2 1  3.720755 CHP212    Amplified
# 3 2  4.658529 COGN415   Amplified
# 4 3  5.322958 COGN440   Amplified
# 5 4  5.996785 COGN453   Amplified
# 6 5  2.920578 COGN496   Amplified
#   1p36 del                                            3p26 del      11q23 del
# 1 LOH p32.3-pter; Gain p34.3-p36.22; Loss p36.22-pter Gain/AI p26.3 None
# 2 Loss p13.2-pter                                     Gain/AI p26.3 cnLOH 23.3
# 3 Unknown                                             Unknown       Unknown
# 4 Unknown                                             Unknown       Unknown
# 5 Unknown                                             Unknown       Unknown
# 6 Unknown                                             Unknown       Unknown
#   17q21-qter unbal gain ALK mutation p53 mutation
# 1 Gain q12-qter         WT           WT
# 2 Gain q12-qter         WT           WT
# 3 Unknown               F1174L       WT
# 4 Unknown               WT           WT
# 5 Unknown               F1174L       WT
# 6 Unknown               Unknown      Unknown

# %%
mycn_validation_gg <-
    ggplot(mycn_validation_df,
           aes(y = vae_111,
               x = `MYCN status`,
               fill = `MYCN status`)) +
  geom_boxplot(alpha = 0.5,
               outlier.alpha = 0) +
  geom_jitter(aes(color = `MYCN status`),
              alpha = 0.7,
              size = 0.9,
              width = 0.2) +
  theme_bw() +
  scale_fill_manual(labels = c("Amplified" = "Amplified",
                               "Not Amplified" = "Not Amplified"),
                    values = c("Amplified" = "#d95f02",
                               "Not Amplified" = "#1b9e77")) +
  scale_color_manual(labels = c("Amplified" = "Amplified",
                                "Not Amplified" = "Not Amplified"),
                     values = c("Amplified" = "#d95f02",
                                "Not Amplified" = "#1b9e77")) +
  ylab("VAE Feature 111 (k = 200)") +
  xlab("") +
  ggtitle("NBL Cell Lines MYCN Status") +
  theme(axis.title.x = element_text(size = 7),
       axis.title.y = element_text(size = 7),
       axis.text.x = element_text(size = 6),
       axis.text.y = element_text(size = 6),
       plot.title = element_text(size = 8,
                                 hjust = 0.5),
       legend.position = "none")

mycn_validation_gg
# Out:
# plot without title

# %% [markdown]
# ## Compile Plot

# %%
# Plot multi panel figure
line_gg_legend <- cowplot::get_legend(line_gg_list[[1]])

full_line_gg <- cowplot::plot_grid(
    line_gg_list[[2]] +
        theme(legend.position = "none") +
    ggtitle("GTEx Sex"),
        line_gg_list[[3]] +
    theme(legend.position = "none") +
        ggtitle("TCGA Sex"),
    labels = c("a", "c")
)

full_line_gg <- cowplot::plot_grid(full_line_gg,
                                   line_gg_legend,
                                   rel_widths = c(1, 0.08),
                                   ncol = 2)

box_gg <- cowplot::plot_grid(
    gtex_sex_gg,
    tcga_sex_gg,
    labels = c("b", "d"),
    ncol = 2
)


full_nbl_gg <- cowplot::plot_grid(
    line_gg_list[[1]] +
        ggtitle("TARGET NBL MYCN Status") +
        theme(legend.position = "bottom"),
    mycn_amp_gg +
        ggtitle("TARGET NBL MYCN Status"),
    mycn_validation_gg +
        ggtitle("NBL Cell Lines MYCN Status"),
    labels = c("e", "f", "g"),
    ncol = 3
)


main_plot <- cowplot::plot_grid(
    full_line_gg,
    box_gg,
    full_nbl_gg,
    nrow = 3
)

main_plot
# Out:
# plot without title

# %%
for(extension in c('.png', '.pdf')) {
  fig_file <- paste0("full_separation_plot", extension)
  fig_file <- file.path("figures", fig_file)
  cowplot::save_plot(filename = fig_file,
                     plot = main_plot,
                     base_height = 180,
                     base_width = 170,
                     units = "mm")
}
